# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### FSQ POI

# %%
# Import modules
import pandas as pd

# %%
# Load dataset 
fsq_poi = pd.read_csv('fsq_poi.csv')
fsq_poi.head()
# Out:
#    distance                                 name  price  rating  \
# 0       127                     Lollipops Gelato    1.0     8.6
# 1       797                 Ripe Kitchen and Bar    2.0     8.4
# 2       821                      Ali's Roti Shop    1.0     8.1
# 3       983             Jimbo's Hamburger Palace    1.0     8.0
# 4       454  Cooler Runnings Jamaican Restaurant    2.0     6.4
#
#    geocodes.main.latitude  geocodes.main.longitude  geocodes.roof.latitude  \
# 0               40.893585               -73.843692               40.893585
# 1               40.898196               -73.838821               40.898196
# 2               40.893950               -73.856803               40.893950
# 3               40.891853               -73.858478               40.891853
# 4               40.898173               -73.850254               40.898173
#
#    geocodes.roof.longitude  req_cat
# 0               -73.843692    13065
# 1               -73.838821    13065
# 2               -73.856803    13065
# 3               -73.858478    13065
# 4               -73.850254    13065

# %%
fsq_poi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   distance                 7000 non-null   int64
#  1   name                     7000 non-null   object
#  2   price                    6255 non-null   float64
#  3   rating                   4677 non-null   float64
#  4   geocodes.main.latitude   7000 non-null   float64
#  5   geocodes.main.longitude  7000 non-null   float64
#  6   geocodes.roof.latitude   6419 non-null   float64
#  7   geocodes.roof.longitude  6419 non-null   float64
#  8   req_cat                  7000 non-null   int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 492.3+ KB

# %%
# Drop irrelevant or repetitive columns
fsq_poi.drop(columns=['geocodes.roof.latitude', 'geocodes.roof.longitude'], inplace=True)
fsq_poi.head()
# Out:
#    distance                                 name  price  rating  \
# 0       127                     Lollipops Gelato    1.0     8.6
# 1       797                 Ripe Kitchen and Bar    2.0     8.4
# 2       821                      Ali's Roti Shop    1.0     8.1
# 3       983             Jimbo's Hamburger Palace    1.0     8.0
# 4       454  Cooler Runnings Jamaican Restaurant    2.0     6.4
#
#    geocodes.main.latitude  geocodes.main.longitude  req_cat
# 0               40.893585               -73.843692    13065
# 1               40.898196               -73.838821    13065
# 2               40.893950               -73.856803    13065
# 3               40.891853               -73.858478    13065
# 4               40.898173               -73.850254    13065

# %%
# Rename columns for better interpretability 
fsq_poi.columns = ['Distance (m)','Name','Price','Rating','Latitude','Longitude','Category']
print(fsq_poi.shape)
fsq_poi.head()
# Out:
# (7000, 7)
#    Distance (m)                                 Name  Price  Rating  \
# 0           127                     Lollipops Gelato    1.0     8.6
# 1           797                 Ripe Kitchen and Bar    2.0     8.4
# 2           821                      Ali's Roti Shop    1.0     8.1
# 3           983             Jimbo's Hamburger Palace    1.0     8.0
# 4           454  Cooler Runnings Jamaican Restaurant    2.0     6.4
#
#     Latitude  Longitude  Category
# 0  40.893585 -73.843692     13065
# 1  40.898196 -73.838821     13065
# 2  40.893950 -73.856803     13065
# 3  40.891853 -73.858478     13065
# 4  40.898173 -73.850254     13065

# %%
# Check for unique values

def unique_values(df):
    columns = df.columns
    for col in columns:
        print('Column Name:', col)
        print('# of Unique Values:', (len(df[col].unique())))
        print('Unique Values:', df[col].unique())
        print('==============================================================')
    
unique_values(fsq_poi)
# Out:
# Column Name: Distance (m)
# # of Unique Values: 1004
# Unique Values: [ 127  797  821 ... 1001 1033 1230]
# ==============================================================
# Column Name: Name
# # of Unique Values: 4535
# Unique Values: ['Lollipops Gelato' 'Ripe Kitchen and Bar' "Ali's Roti Shop" ...
#  'Flavors Corner' 'Ooi Sushi and Bar' 'Kum Fung Chinese Restaurant']
# ==============================================================
# Column Name: Price
# # of Unique Values: 5
# Unique Values: [ 1.  2. nan  3.  4.]
# ==============================================================
# Column Name: Rating
# # of Unique Values: 52
# Unique Values: [8.6 8.4 8.1 8.  6.4 6.7 6.6 5.8 nan 5.7 8.2 7.9 7.6 7.3 6.8 5.9 6.3 6.1
#  8.3 7.5 7.7 7.2 7.  6.9 6.  6.5 5.6 8.9 8.7 7.8 7.1 6.2 5.3 8.5 9.2 9.
#  5.4 7.4 8.8 5.2 5.5 5.  4.7 9.1 9.3 9.4 9.5 9.6 5.1 4.8 4.9 4.5]
# ==============================================================
# Column Name: Latitude
# # of Unique Values: 4982
# Unique Values: [40.893585 40.898196 40.89395  ... 40.755323 40.755997 40.621817]
# ==============================================================
# Column Name: Longitude
# # of Unique Values: 4989
# Unique Values: [-73.843692 -73.838821 -73.856803 ... -73.945402 -73.942414 -74.07237 ]
# ==============================================================
# Column Name: Category
# # of Unique Values: 1
# Unique Values: [13065]
# ==============================================================

# %%
# Check for null values
fsq_poi.isnull().sum()
# Out:
# Distance (m)       0
# Name               0
# Price            745
# Rating          2323
# Latitude           0
# Longitude          0
# Category           0
# dtype: int64

# %% [markdown]
# There are null values in price and rating. However it has low impact, as it simply signifies that some restuarants have no price and rating information, which does not effect our objective.

# %%
# Check for duplicate rows
fsq_poi[fsq_poi.duplicated()]
# Out:
#       Distance (m)                    Name  Price  Rating  Latitude  \
# 5637           500  El Pollo II Restaurant    1.0     7.2  40.59068
#
#       Longitude  Category
# 5637 -74.191997     13065

# %%
# 1 duplicate row found, remove from DataFrame
fsq_poi = fsq_poi.drop([5637])

# Confirm removal
fsq_poi[fsq_poi.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Distance (m), Name, Price, Rating, Latitude, Longitude, Category]
# Index: []

# %%
# See variance in numeric feautures
fsq_poi.describe()
# Out:
#        Distance (m)        Price       Rating     Latitude    Longitude  \
# count    6999.00000  6254.000000  4676.000000  6999.000000  6999.000000
# mean      578.36248     1.597058     7.808618    40.711354   -73.937832
# std       261.53718     0.705532     1.001289     0.093952     0.112958
# min         3.00000     1.000000     4.500000    40.507106   -74.251372
# 25%       375.50000     1.000000     7.100000    40.631761   -73.992029
# 50%       585.00000     1.000000     8.000000    40.711880   -73.928118
# 75%       790.00000     2.000000     8.700000    40.773461   -73.857604
# max      4095.00000     4.000000     9.600000    40.912863   -73.698338
#
#        Category
# count    6999.0
# mean    13065.0
# std         0.0
# min     13065.0
# 25%     13065.0
# 50%     13065.0
# 75%     13065.0
# max     13065.0

# %%
# Preview cleaned dataset
print(fsq_poi.shape)
fsq_poi.head()
# Out:
# (6999, 7)
#    Distance (m)                                 Name  Price  Rating  \
# 0           127                     Lollipops Gelato    1.0     8.6
# 1           797                 Ripe Kitchen and Bar    2.0     8.4
# 2           821                      Ali's Roti Shop    1.0     8.1
# 3           983             Jimbo's Hamburger Palace    1.0     8.0
# 4           454  Cooler Runnings Jamaican Restaurant    2.0     6.4
#
#     Latitude  Longitude  Category
# 0  40.893585 -73.843692     13065
# 1  40.898196 -73.838821     13065
# 2  40.893950 -73.856803     13065
# 3  40.891853 -73.858478     13065
# 4  40.898173 -73.850254     13065

# %%
# Export cleaned dataset to csv
fsq_poi.to_csv('fsq_poi_clean.csv')

# %% [markdown]
# ### Yelp POI

# %%
# Load dataset
yelp_poi = pd.read_csv('yelp_poi.csv')
yelp_poi.head()
# Out:
#                        id                                alias  \
# 0  fLJw_HGD01RTQ_WqlJf6Ew    ripe-kitchen-and-bar-mount-vernon
# 1  iJci5KN7H39D3JXHiNBDKw  h-i-m-ital-health-food-market-bronx
# 2  IcEafi60F4pyEHaM4lR4Wg                 alis-roti-shop-bronx
# 3  h5dm87qaqHeTBGcqTi9hWg               paulas-soul-cafe-bronx
# 4  _XMhEsFSFUQsuKae7zzFZg                     jerk-house-bronx
#
#                             name  \
# 0             Ripe Kitchen & Bar
# 1  H.I.M Ital Health Food Market
# 2                Ali's Roti Shop
# 3              Paula's Soul Cafe
# 4                     Jerk House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/NCpeGV...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/Tze_Nm...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/6SQMma...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/yfGmup...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/Jx4v64...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ripe-kitchen-and-bar-...           287
# 1  https://www.yelp.com/biz/h-i-m-ital-health-foo...            47
# 2  https://www.yelp.com/biz/alis-roti-shop-bronx?...           104
# 3  https://www.yelp.com/biz/paulas-soul-cafe-bron...           202
# 4  https://www.yelp.com/biz/jerk-house-bronx?adju...            62
#
#                                           categories  rating  \
# 0     [{'alias': 'caribbean', 'title': 'Caribbean'}]     4.0
# 1  [{'alias': 'healthmarkets', 'title': 'Health M...     4.5
# 2  [{'alias': 'trinidadian', 'title': 'Trinidadia...     4.0
# 3  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.0
# 4     [{'alias': 'caribbean', 'title': 'Caribbean'}]     3.5
#
#              transactions  ... coordinates.longitude      location.address1  \
# 0            ['delivery']  ...            -73.838821    151 W Sandford Blvd
# 1            ['delivery']  ...            -73.854665  4374B White Plains Rd
# 2                      []  ...            -73.856840   4220 White Plains Rd
# 3  ['delivery', 'pickup']  ...            -73.855680         746 E 233rd St
# 4  ['delivery', 'pickup']  ...            -73.856480      4246 White Plains
#
#   location.address2  location.address3  location.city  location.zip_code  \
# 0               NaN                NaN   Mount Vernon              10550
# 1               NaN                NaN          Bronx              10466
# 2               NaN                NaN          Bronx              10466
# 3               NaN                NaN          Bronx              10466
# 4               NaN                NaN          Bronx              10466
#
#   location.country location.state  \
# 0               US             NY
# 1               US             NY
# 2               US             NY
# 3               US             NY
# 4               US             NY
#
#                             location.display_address      req_cat
# 0  ['151 W Sandford Blvd', 'Mount Vernon, NY 10550']  restaurants
# 1       ['4374B White Plains Rd', 'Bronx, NY 10466']  restaurants
# 2        ['4220 White Plains Rd', 'Bronx, NY 10466']  restaurants
# 3              ['746 E 233rd St', 'Bronx, NY 10466']  restaurants
# 4           ['4246 White Plains', 'Bronx, NY 10466']  restaurants
#
# [5 rows x 25 columns]

# %%
yelp_poi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7115 entries, 0 to 7114
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        7115 non-null   object
#  1   alias                     7115 non-null   object
#  2   name                      7115 non-null   object
#  3   image_url                 7058 non-null   object
#  4   is_closed                 7115 non-null   bool
#  5   url                       7115 non-null   object
#  6   review_count              7115 non-null   int64
#  7   categories                7115 non-null   object
#  8   rating                    7115 non-null   float64
#  9   transactions              7115 non-null   object
#  10  price                     6116 non-null   object
#  11  phone                     6924 non-null   float64
#  12  display_phone             6924 non-null   object
#  13  distance                  7115 non-null   float64
#  14  coordinates.latitude      7115 non-null   float64
#  15  coordinates.longitude     7115 non-null   float64
#  16  location.address1         6949 non-null   object
#  17  location.address2         205 non-null    object
#  18  location.address3         53 non-null     object
#  19  location.city             7115 non-null   object
#  20  location.zip_code         7115 non-null   int64
#  21  location.country          7115 non-null   object
#  22  location.state            7115 non-null   object
#  23  location.display_address  7115 non-null   object
#  24  req_cat                   7115 non-null   object
# dtypes: bool(1), float64(5), int64(2), object(17)
# memory usage: 1.3+ MB

# %%
# yelp_poi.iloc[:,10:]
yelp_poi.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address',
#        'req_cat'],
#       dtype='object')

# %%
# Drop irrelevant or repetitive columns
yelp_poi.drop(columns=['id','alias','image_url','is_closed','url','categories','transactions','phone',
                        'display_phone','location.address2','location.address3',
                        'location.city','location.zip_code','location.country',
                        'location.state','location.display_address'],
                         inplace=True)
yelp_poi.head()
# Out:
#                             name  review_count  rating price    distance  \
# 0             Ripe Kitchen & Bar           287     4.0    $$  805.077589
# 1  H.I.M Ital Health Food Market            47     4.5     $  715.467929
# 2                Ali's Roti Shop           104     4.0     $  809.642747
# 3              Paula's Soul Cafe           202     3.0    $$  746.891106
# 4                     Jerk House            62     3.5    $$  771.525854
#
#    coordinates.latitude  coordinates.longitude      location.address1  \
# 0             40.898214             -73.838821    151 W Sandford Blvd
# 1             40.897633             -73.854665  4374B White Plains Rd
# 2             40.894000             -73.856840   4220 White Plains Rd
# 3             40.892690             -73.855680         746 E 233rd St
# 4             40.894640             -73.856480      4246 White Plains
#
#        req_cat
# 0  restaurants
# 1  restaurants
# 2  restaurants
# 3  restaurants
# 4  restaurants

# %%
# Rename columns for better interpretability 
yelp_poi.columns = ['Name','Reviews','Rating','Price',
                    'Distance (m)','Latitude','Longitude','Address','Category']
                    
print(yelp_poi.shape)
yelp_poi.head()
# Out:
# (7115, 9)
#                             Name  Reviews  Rating Price  Distance (m)  \
# 0             Ripe Kitchen & Bar      287     4.0    $$    805.077589
# 1  H.I.M Ital Health Food Market       47     4.5     $    715.467929
# 2                Ali's Roti Shop      104     4.0     $    809.642747
# 3              Paula's Soul Cafe      202     3.0    $$    746.891106
# 4                     Jerk House       62     3.5    $$    771.525854
#
#     Latitude  Longitude                Address     Category
# 0  40.898214 -73.838821    151 W Sandford Blvd  restaurants
# 1  40.897633 -73.854665  4374B White Plains Rd  restaurants
# 2  40.894000 -73.856840   4220 White Plains Rd  restaurants
# 3  40.892690 -73.855680         746 E 233rd St  restaurants
# 4  40.894640 -73.856480      4246 White Plains  restaurants

# %%
# Check for unique values
unique_values(yelp_poi)
# Out:
# Column Name: Name
# # of Unique Values: 4163
# Unique Values: ['Ripe Kitchen & Bar' 'H.I.M Ital Health Food Market' "Ali's Roti Shop"
#  ... 'The Local Bar and Cafe' 'Kum Fung Chinese Restaurant' 'Amendment 18']
# ==============================================================
# Column Name: Reviews
# # of Unique Values: 1072
# Unique Values: [ 287   47  104 ...  784  397 1028]
# ==============================================================
# Column Name: Rating
# # of Unique Values: 9
# Unique Values: [4.  4.5 3.  3.5 5.  2.5 2.  1.5 1. ]
# ==============================================================
# Column Name: Price
# # of Unique Values: 5
# Unique Values: ['$$' '$' '$$$' nan '$$$$']
# ==============================================================
# Column Name: Distance (m)
# # of Unique Values: 7048
# Unique Values: [ 805.0775886   715.46792863  809.64274698 ...  825.92920937 1049.84712452
#  1076.21508396]
# ==============================================================
# Column Name: Latitude
# # of Unique Values: 4402
# Unique Values: [40.898214   40.897633   40.894      ... 40.7495622  40.621825
#  40.62530162]
# ==============================================================
# Column Name: Longitude
# # of Unique Values: 4400
# Unique Values: [-73.838821   -73.854665   -73.85684    ... -73.9477008  -74.07234
#  -74.07454516]
# ==============================================================
# Column Name: Address
# # of Unique Values: 4266
# Unique Values: ['151 W Sandford Blvd' '4374B White Plains Rd' '4220 White Plains Rd' ...
#  '13-02 44th Ave' '838 Bay St' '691 Bay St']
# ==============================================================
# Column Name: Category
# # of Unique Values: 1
# Unique Values: ['restaurants']
# ==============================================================

# %%
# Check for nulls
yelp_poi.isnull().sum()
# Out:
# Name              0
# Reviews           0
# Rating            0
# Price           999
# Distance (m)      0
# Latitude          0
# Longitude         0
# Address         166
# Category          0
# dtype: int64

# %% [markdown]
# There are null values in price and address. However it has low impact, as it simply signifies that some restuarants have no price and address information, which does not effect our objective.
#
# Additionally, we have the coordinates which will be the main features used for city mapping.

# %%
# Check for duplicates
yelp_poi[yelp_poi.duplicated()]

# No duplicates
# Out:
# Empty DataFrame
# Columns: [Name, Reviews, Rating, Price, Distance (m), Latitude, Longitude, Address, Category]
# Index: []

# %%
# See variance in numeric feautures
yelp_poi.describe()
# Out:
#             Reviews       Rating  Distance (m)     Latitude    Longitude
# count   7115.000000  7115.000000   7115.000000  7115.000000  7115.000000
# mean     396.188897     3.916936   1571.646996    40.713105   -73.942424
# std      863.333845     0.630598   4323.548896     0.093239     0.113619
# min        1.000000     1.000000     16.138170    40.205016   -74.448224
# 25%       39.000000     3.500000    420.978899    40.634212   -73.994440
# 50%      127.000000     4.000000    681.842680    40.716641   -73.939610
# 75%      368.000000     4.500000    936.679688    40.771113   -73.865726
# max    14361.000000     5.000000  77147.675762    40.915940   -73.100648

# %%
# Preview cleaned dataset
print(yelp_poi.shape)
yelp_poi.head()
# Out:
# (7115, 9)
#                             Name  Reviews  Rating Price  Distance (m)  \
# 0             Ripe Kitchen & Bar      287     4.0    $$    805.077589
# 1  H.I.M Ital Health Food Market       47     4.5     $    715.467929
# 2                Ali's Roti Shop      104     4.0     $    809.642747
# 3              Paula's Soul Cafe      202     3.0    $$    746.891106
# 4                     Jerk House       62     3.5    $$    771.525854
#
#     Latitude  Longitude                Address     Category
# 0  40.898214 -73.838821    151 W Sandford Blvd  restaurants
# 1  40.897633 -73.854665  4374B White Plains Rd  restaurants
# 2  40.894000 -73.856840   4220 White Plains Rd  restaurants
# 3  40.892690 -73.855680         746 E 233rd St  restaurants
# 4  40.894640 -73.856480      4246 White Plains  restaurants

# %%
# Export cleaned dataset to csv
yelp_poi.to_csv('yelp_poi_cleaned.csv')

# %% [markdown]
# ### Google Places POI

# %%
gp_poi = pd.read_csv('google_places_poi.csv')
gp_poi.head()
# Out:
#   business_status                                               icon  \
# 0     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#   icon_background_color                                 icon_mask_base_uri  \
# 0               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                         name  \
# 0         Ripe Kitchen & Bar
# 1           New China Garden
# 2                    Dunkin'
# 3                     Subway
# 4  Popeyes Louisiana Kitchen
#
#                                               photos  \
# 0  [{'height': 2471, 'html_attributions': ['<a hr...
# 1  [{'height': 4032, 'html_attributions': ['<a hr...
# 2  [{'height': 3000, 'html_attributions': ['<a hr...
# 3  [{'height': 766, 'html_attributions': ['<a hre...
# 4  [{'height': 1192, 'html_attributions': ['<a hr...
#
#                       place_id  price_level  rating  \
# 0  ChIJ9aOdYiyNwokRS49czrNTQo4          2.0     4.3
# 1  ChIJcVDAYNfywokRPUaKrm0UBpg          1.0     3.9
# 2  ChIJ--58aynzwokRqSvaRDKwX1M          1.0     3.8
# 3  ChIJAy-ibCnzwokRdmkKGd1Yzhw          1.0     3.6
# 4  ChIJXVacFSvzwokRa3VpQDuwRDE          1.0     3.8
#
#                      reference  ... geometry.location.lng  \
# 0  ChIJ9aOdYiyNwokRS49czrNTQo4  ...            -73.838855
# 1  ChIJcVDAYNfywokRPUaKrm0UBpg  ...            -73.853364
# 2  ChIJ--58aynzwokRqSvaRDKwX1M  ...            -73.849089
# 3  ChIJAy-ibCnzwokRdmkKGd1Yzhw  ...            -73.849152
# 4  ChIJXVacFSvzwokRa3VpQDuwRDE  ...            -73.843383
#
#   geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                       40.899498                       -73.837452
# 1                       40.899306                       -73.852100
# 2                       40.891936                       -73.847664
# 3                       40.891828                       -73.847659
# 4                       40.890762                       -73.842012
#
#   geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                       40.896800                       -73.840150
# 1                       40.896608                       -73.854798
# 2                       40.889239                       -73.850362
# 3                       40.889130                       -73.850357
# 4                       40.888064                       -73.844710
#
#    opening_hours.open_now        plus_code.compound_code  \
# 0                    True  V5X6+7F Mount Vernon, NY, USA
# 1                    True     V4XW+5M The Bronx, NY, USA
# 2                    True      V5R2+59 New York, NY, USA
# 3                    True      V5R2+58 New York, NY, USA
# 4                    True      V5Q4+QJ New York, NY, USA
#
#    plus_code.global_code  permanently_closed     req_cat
# 0            87G8V5X6+7F                 NaN  restaurant
# 1            87G8V4XW+5M                 NaN  restaurant
# 2            87G8V5R2+59                 NaN  restaurant
# 3            87G8V5R2+58                 NaN  restaurant
# 4            87G8V5Q4+QJ                 NaN  restaurant
#
# [5 rows x 25 columns]

# %%
gp_poi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5619 entries, 0 to 5618
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   business_status                  5619 non-null   object
#  1   icon                             5619 non-null   object
#  2   icon_background_color            5619 non-null   object
#  3   icon_mask_base_uri               5619 non-null   object
#  4   name                             5619 non-null   object
#  5   photos                           5442 non-null   object
#  6   place_id                         5619 non-null   object
#  7   price_level                      4786 non-null   float64
#  8   rating                           5522 non-null   float64
#  9   reference                        5619 non-null   object
#  10  scope                            5619 non-null   object
#  11  types                            5619 non-null   object
#  12  user_ratings_total               5522 non-null   float64
#  13  vicinity                         5619 non-null   object
#  14  geometry.location.lat            5619 non-null   float64
#  15  geometry.location.lng            5619 non-null   float64
#  16  geometry.viewport.northeast.lat  5619 non-null   float64
#  17  geometry.viewport.northeast.lng  5619 non-null   float64
#  18  geometry.viewport.southwest.lat  5619 non-null   float64
#  19  geometry.viewport.southwest.lng  5619 non-null   float64
#  20  opening_hours.open_now           5368 non-null   object
#  21  plus_code.compound_code          5617 non-null   object
#  22  plus_code.global_code            5617 non-null   object
#  23  permanently_closed               157 non-null    object
#  24  req_cat                          5619 non-null   object
# dtypes: float64(9), object(16)
# memory usage: 1.1+ MB

# %%
# gp_poi.iloc[0:5,10:]
gp_poi.columns
# Out:
# Index(['business_status', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'price_level',
#        'rating', 'reference', 'scope', 'types', 'user_ratings_total',
#        'vicinity', 'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'opening_hours.open_now', 'plus_code.compound_code',
#        'plus_code.global_code', 'permanently_closed', 'req_cat'],
#       dtype='object')

# %%
# Drop irrelevant or repetitive columns
gp_poi.drop(columns=['business_status','icon','icon_background_color','icon_mask_base_uri',
                    'photos','place_id','reference','scope','types','geometry.viewport.northeast.lat',
                    'geometry.viewport.northeast.lng','geometry.viewport.southwest.lat',
                    'geometry.viewport.southwest.lng','opening_hours.open_now',
                    'plus_code.compound_code','plus_code.global_code','permanently_closed'], 
                    inplace=True)

gp_poi.head()
# Out:
#                         name  price_level  rating  user_ratings_total  \
# 0         Ripe Kitchen & Bar          2.0     4.3               714.0
# 1           New China Garden          1.0     3.9                85.0
# 2                    Dunkin'          1.0     3.8               280.0
# 3                     Subway          1.0     3.6               121.0
# 4  Popeyes Louisiana Kitchen          1.0     3.8               467.0
#
#                                     vicinity  geometry.location.lat  \
# 0  151 West Sandford Boulevard, Mount Vernon              40.898209
# 1               724 Nereid Avenue, The Bronx              40.897919
# 2           980 East 233rd Street, The Bronx              40.890459
# 3           980 East 233rd Street, The Bronx              40.890468
# 4          1201 East 233rd Street, The Bronx              40.889492
#
#    geometry.location.lng     req_cat
# 0             -73.838855  restaurant
# 1             -73.853364  restaurant
# 2             -73.849089  restaurant
# 3             -73.849152  restaurant
# 4             -73.843383  restaurant

# %%
# Rename columns for better interpretability
gp_poi.columns = ['Name','Price','Rating','Reviews','Address','Latitude','Longitude','Category']
print(gp_poi.shape)
gp_poi.head()
# Out:
# (5619, 8)
#                         Name  Price  Rating  Reviews  \
# 0         Ripe Kitchen & Bar    2.0     4.3    714.0
# 1           New China Garden    1.0     3.9     85.0
# 2                    Dunkin'    1.0     3.8    280.0
# 3                     Subway    1.0     3.6    121.0
# 4  Popeyes Louisiana Kitchen    1.0     3.8    467.0
#
#                                      Address   Latitude  Longitude    Category
# 0  151 West Sandford Boulevard, Mount Vernon  40.898209 -73.838855  restaurant
# 1               724 Nereid Avenue, The Bronx  40.897919 -73.853364  restaurant
# 2           980 East 233rd Street, The Bronx  40.890459 -73.849089  restaurant
# 3           980 East 233rd Street, The Bronx  40.890468 -73.849152  restaurant
# 4          1201 East 233rd Street, The Bronx  40.889492 -73.843383  restaurant

# %%
# Check for unique values
unique_values(gp_poi)
# Out:
# Column Name: Name
# # of Unique Values: 3078
# Unique Values: ['Ripe Kitchen & Bar' 'New China Garden' "Dunkin'" ... 'Exquisito'
#  'Greek Panorama' 'Kum Fung']
# ==============================================================
# Column Name: Price
# # of Unique Values: 5
# Unique Values: [ 2.  1. nan  3.  4.]
# ==============================================================
# Column Name: Rating
# # of Unique Values: 35
# Unique Values: [4.3 3.9 3.8 3.6 3.3 4.2 3.7 4.1 2.2 1.  4.  4.5 5.  4.6 2.9 4.4 4.7 3.
#  3.4 2.4 3.2 2.5 3.5 2.7 3.1 2.8 4.9 nan 2.  2.6 2.1 4.8 2.3 1.9 1.8]
# ==============================================================
# Column Name: Reviews
# # of Unique Values: 1434
# Unique Values: [ 714.   85.  280. ... 1007. 1291. 1732.]
# ==============================================================
# Column Name: Address
# # of Unique Values: 3883
# Unique Values: ['151 West Sandford Boulevard, Mount Vernon'
#  '724 Nereid Avenue, The Bronx' '980 East 233rd Street, The Bronx' ...
#  '24 -11 41st Avenue, Long Island City' '455 Main Street, New York'
#  '838 Bay Street, Staten Island']
# ==============================================================
# Column Name: Latitude
# # of Unique Values: 4000
# Unique Values: [40.8982087 40.897919  40.8904588 ... 40.7535229 40.759305  40.6218795]
# ==============================================================
# Column Name: Longitude
# # of Unique Values: 3996
# Unique Values: [-73.8388554 -73.8533641 -73.8490889 ... -73.9388994 -73.952917
#  -74.0722633]
# ==============================================================
# Column Name: Category
# # of Unique Values: 1
# Unique Values: ['restaurant']
# ==============================================================

# %%
# Check for nulls
gp_poi.isnull().sum()
# Out:
# Name           0
# Price        833
# Rating        97
# Reviews       97
# Address        0
# Latitude       0
# Longitude      0
# Category       0
# dtype: int64

# %% [markdown]
# There are null values in price, rating, and reviews. However it has low impact, as it simply signifies that some restuarants have no price, rating, or review information, which does not effect our objective.

# %%
# Check for duplicates
gp_poi = gp_poi[gp_poi.duplicated()]
len(gp_poi)
# Out:
# 1578

# %%
# Duplicate rows found, remove from DataFrame
gp_poi = gp_poi.drop_duplicates()

# Confirm removal
gp_poi[gp_poi.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Price, Rating, Reviews, Address, Latitude, Longitude, Category]
# Index: []

# %%
# See variance in numeric feautures
gp_poi.describe()
# Out:
#              Price       Rating       Reviews     Latitude    Longitude
# count  1116.000000  1246.000000   1246.000000  1260.000000  1260.000000
# mean      1.660394     4.083226    740.940610    40.713778   -73.951417
# std       0.671181     0.439148   1260.821341     0.094919     0.111364
# min       1.000000     1.000000      1.000000    40.522106   -74.238666
# 25%       1.000000     3.900000    148.000000    40.626667   -74.000674
# 50%       2.000000     4.200000    360.500000    40.713171   -73.944073
# 75%       2.000000     4.400000    847.000000    40.786754   -73.869725
# max       4.000000     5.000000  19357.000000    40.894788   -73.707534

# %%
# Preview cleaned dataset
print(gp_poi.shape)
gp_poi.head()
# Out:
# (1260, 8)
#                         Name  Price  Rating  Reviews  \
# 54  Prime 33 Banquet hall #1    2.0     4.3    150.0
# 80        An Beal Bocht Cafe    2.0     4.6    534.0
# 82    Goodfellas Riverdale 🍕    2.0     3.8    171.0
# 84      Corner Cafe & Bakery    1.0     4.4    164.0
# 85               Salvatore's    2.0     4.4    656.0
#
#                              Address   Latitude  Longitude    Category
# 54    3323 Merritt Avenue, The Bronx  40.881788 -73.826755  restaurant
# 80  445 West 238th Street, The Bronx  40.887375 -73.904953  restaurant
# 82      3661 Waldo Avenue, The Bronx  40.887026 -73.904387  restaurant
# 84  3718 Riverdale Avenue, The Bronx  40.887266 -73.906920  restaurant
# 85  3738 Riverdale Avenue, The Bronx  40.887631 -73.906955  restaurant

# %% [markdown]
# A pizza slice!
#
# The names can be kept as is, even with an emoji, as it will not affect our modelling, as the name column will not be used.

# %%
# Export cleaned dataset to csv
gp_poi.to_csv('google_places_poi_clean.csv')
